# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from google.colab import files

# %%
print(files.os.listdir('sample_data'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-52b785799f39> in <module>()
# ----> 1 print(files.os.listdir('sample_data'))
#
# AttributeError: module 'google.colab.files' has no attribute 'os'

# %% [markdown]
# # New Section
